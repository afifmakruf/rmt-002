# %%
# !pip install selenium bs4

# %%
# !pip install requests

# %%
from selenium import webdriver
import requests
from bs4 import BeautifulSoup

# %%
driver = webdriver.Chrome()

# %%
driver.close()

# %%
page = requests.get('https://www.gramedia.com/categories/buku')
page
# Out:
# <Response [200]>

# %%
import time

# %%
driver = webdriver.Chrome()
driver.get('https://www.gramedia.com/categories/buku')
time.sleep(4)
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
driver.close()

# %%
contoh_data = soup.find('h2', {'class':'line-clamp-2 text-xs-medium text-neutral-700'})

judul = []

for data in soup.find_all('h2', {'class':'line-clamp-2 text-xs-medium text-neutral-700'}):
    judul.append(data.get_text())

# %%
judul
# Out:
# ['New Media dan Dakwah',
#  'Tafsiran Alkitab bagi Orang Percaya, Perjanjian Baru - Buku 2',
#  'Rumi : Samudra Pesan dan Nasihat-Nasihatnya',
#  'Fiqih Muslim: Problematika Kaum Laki-laki',
#  'Kisah Akhir Hayat Orang-Orang Zhalim',
#  'Fiqih Muslimah : Problematika Kaum Perempuan',
#  'Theology of Hope',
#  'Pada Jejak Sang Kekasih',
#  'Moderasi Beragama dan Pergulatan Wacana dalam Ruang Publik',
#  'Panduan Muslimah Jatuh Cinta Lewat Jalur Langit',
#  'Rahasia Sukses Budidaya Ikan Patin Secara Intensif',
#  'Rahasia Sukses Budi Daya Burung Walet',
#  'Buku Pintar Teknik Produksi Benih Ikan, Berdasarkan Cara Pembenihan Ikan yang Baik',
#  'Pedoman Sukses Budi Daya Ikan Lele',
#  'Untung Dari Bisnis Domba & Kambing Ala Mt Farm',
#  'Potensi Transfer Embrio Kerbau Di Indonesia',
#  'Satwa Langka Di Hutan Tropis, Laut & Samudra, Kepulauan',
#  'Ayam Pelung : Klangenan Hingga Kontes',
#  '101 Kiat Mengatasi Permasalahan Budi Daya Walet',
#  'Beternak Maggot Black Soldier Fly',
# ...

# %%
<div class="truncate text-2xs-medium text-neutral-500" data-testid="productCardAuthor">William MacDonald</div>

# %% [markdown]
# tags : div
# atribut : class
# value : truncate text-2xs-medium text-neutral-500

# %%
author = []

# for data in soup.find_all('div', {'class':'truncate text-2xs-medium text-neutral-500'})

author += [author.get_text() for author in soup.find_all('div', {'class':'truncate text-2xs-medium text-neutral-500'})]

# %%
author
# Out:
# ['William MacDonald',
#  'Sony Adams',
#  'Mikail Khonsu',
#  "Sa'ad Yusuf Abu Aziz",
#  'Mikail Khonsu',
#  'Komaruddin Hidayat',
#  'Adham Syarqawi',
#  'Prof. Dr. Aksin Wijaya, dkk.',
#  'Ummu Kalsum IQT & Rizki Ayu Amaliah',
#  'Hadi Tribowo',
#  'Hadi Tribowo',
#  'Hardaningsih -',
#  'Hadi Tribowo',
#  'Mitra Tani Farm',
#  'Tinda Afriani, Dkk',
#  'Agus Abdurahman',
#  'Drs. Arief Budiman',
#  'Kis Dewantoro Dkk',
#  'Nurul Indarti, Hardo Firmana Given Grace Manik',
#  'Septiawan Santana K.',
#  'Dr. Aji Septiaji, M.Pd.',
#  'Utami Pratiwi S.Pd.',
#  'Dr. Fita Fathurokhmah, M.Si.',
#  'Fariza Yusuf Maulana, Mohamad Ulin Nuha',
#  'Tristanti Tri Wahyuni',
#  'Nanang martono & Rahma Isnania',
#  'Dr. Ir. Bagus Sumargo, M.Si., dkk.',
#  'Asti Musman',
#  'Ir. Taufik Priambodo',
#  'UNTUNG WIDYANTO, DKK.',
#  'Dmaximus Arc',
#  'Asti Musman',
#  'DYAN AGUSTIN; NINIEK ANGGRIANI',
#  'Imelda Akmal',
#  'Parmonangan Manurung',
#  'Prof. Dr. Ir. Hj. Zoer`Aini Djamal Irwan, MS. Ak.V']

# %% [markdown]
# <img alt="Rumi : Samudra Pesan dan Nasihat-Nasihatnya" data-testid="productCardImage" data-sentry-element="Image" data-sentry-source-file="ProductCard.tsx" loading="lazy" decoding="async" data-nimg="fill" class="object-contain" src="https://image.gramedia.net/rs:fit:256:0/plain/https://cdn.gramedia.com/uploads/products/tas4-2aidr.jpg" style="position: absolute; height: 100%; width: 100%; inset: 0px; color: transparent;">

# %%
data['src']

# %%
image = []

image += [data['src'] for data in soup.find_all('img', {'class':'object-contain'})]

author += [author.get_text() for author in soup.find_all('div', {'class':'truncate text-2xs-medium text-neutral-500'})]

# %%
image
# Out:
# ['https://image.gramedia.net/rs:fit:256:0/plain/https://cdn.gramedia.com/uploads/products/i8w0caa250.jpg',
#  'https://image.gramedia.net/rs:fit:256:0/plain/https://cdn.gramedia.com/uploads/products/a-abannene.jpg',
#  'https://image.gramedia.net/rs:fit:256:0/plain/https://cdn.gramedia.com/uploads/products/tas4-2aidr.jpg',
#  'https://image.gramedia.net/rs:fit:256:0/plain/https://cdn.gramedia.com/uploads/products/imx7-ol1ie.png',
#  'https://image.gramedia.net/rs:fit:256:0/plain/https://cdn.gramedia.com/uploads/products/g-nyy59-s8.jpg',
#  'https://image.gramedia.net/rs:fit:256:0/plain/https://cdn.gramedia.com/uploads/products/uemr2b8xa0.jpg',
#  'https://image.gramedia.net/rs:fit:256:0/plain/https://cdn.gramedia.com/uploads/products/4y5f2p2c5o.jpeg',
#  'https://image.gramedia.net/rs:fit:256:0/plain/https://cdn.gramedia.com/uploads/products/5apa5a0aes.jpg',
#  'https://image.gramedia.net/rs:fit:256:0/plain/https://cdn.gramedia.com/uploads/products/-prvxrzaba.png',
# ...

# %%
for data in soup.find_all('img', {'class':'object-contain'}):
    print(data['src'])
# Out:
# https://image.gramedia.net/rs:fit:256:0/plain/https://cdn.gramedia.com/uploads/products/i8w0caa250.jpg
# https://image.gramedia.net/rs:fit:256:0/plain/https://cdn.gramedia.com/uploads/products/a-abannene.jpg
# https://image.gramedia.net/rs:fit:256:0/plain/https://cdn.gramedia.com/uploads/products/tas4-2aidr.jpg
# https://image.gramedia.net/rs:fit:256:0/plain/https://cdn.gramedia.com/uploads/products/imx7-ol1ie.png
# https://image.gramedia.net/rs:fit:256:0/plain/https://cdn.gramedia.com/uploads/products/g-nyy59-s8.jpg
# https://image.gramedia.net/rs:fit:256:0/plain/https://cdn.gramedia.com/uploads/products/uemr2b8xa0.jpg
# https://image.gramedia.net/rs:fit:256:0/plain/https://cdn.gramedia.com/uploads/products/4y5f2p2c5o.jpeg
# https://image.gramedia.net/rs:fit:256:0/plain/https://cdn.gramedia.com/uploads/products/5apa5a0aes.jpg
# https://image.gramedia.net/rs:fit:256:0/plain/https://cdn.gramedia.com/uploads/products/-prvxrzaba.png
# ...

# %% [markdown]
# <a data-sentry-element="LinkComponenent" data-sentry-source-file="ProductCard.tsx" href="https://www.gramedia.com/products/fiqih-muslim-problematika-kaum-lakilaki">

# %%
link_web = []
link_web += [data['href'] for data in soup.find_all('a', {'data-sentry-element':'LinkComponenent'})]
image += [data['src'] for data in soup.find_all('img', {'class':'object-contain'})]

author += [author.get_text() for author in soup.find_all('div', {'class':'truncate text-2xs-medium text-neutral-500'})]

# %%
link_web
# Out:
# ['https://www.gramedia.com/products/new-media-dan-dakwah',
#  'https://www.gramedia.com/products/tafsiran-alkitab-bagi-orang-percaya-perjanjian-baru--buku-2',
#  'https://www.gramedia.com/products/rumi--samudra-pesan-dan-nasihatnasihatnya',
#  'https://www.gramedia.com/products/fiqih-muslim-problematika-kaum-lakilaki',
#  'https://www.gramedia.com/products/kisah-akhir-hayat-orangorang-zhalim',
#  'https://www.gramedia.com/products/fiqih-muslimah--problematika-kaum-perempuan',
#  'https://www.gramedia.com/products/theology-of-hope',
#  'https://www.gramedia.com/products/pada-jejak-sang-kekasih',
#  'https://www.gramedia.com/products/moderasi-beragama-dan-pergulatan-wacana-dalam-ruang-publik',
#  'https://www.gramedia.com/products/panduan-muslimah-jatuh-cinta-lewat-jalur-langit',
#  'https://www.gramedia.com/products/rahasia-sukses-budidaya-ikan-patin-secara-intensif',
#  'https://www.gramedia.com/products/rahasia-sukses-budidaya-burung-walet',
# ...

# %%
judul
author
image
link_web

# %%
import pandas as pd

# %%
df_scrap = pd.DataFrame()

# %%
df_scrap = pd.DataFrame()

df_scrap['judul'] = judul
df_scrap['author_buku'] = author
df_scrap['link_gambar'] = image
df_scrap['link_product'] = link_web
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[99], line 4
#       1 df_scrap = pd.DataFrame()
#       3 df_scrap['judul'] = judul
# ----> 4 df_scrap['author_buku'] = author
#       5 df_scrap['link_gambar'] = image
#       6 df_scrap['link_product'] = link_web
#
# File /opt/anaconda3/envs/test/lib/python3.10/site-packages/pandas/core/frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File /opt/anaconda3/envs/test/lib/python3.10/site-packages/pandas/core/frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
#    4522     ensure homogeneity.
#    4523     """
# ...

# %%
df_scrap
# Out:
#                                                 judul
# 0                                New Media dan Dakwah
# 1   Tafsiran Alkitab bagi Orang Percaya, Perjanjia...
# 2         Rumi : Samudra Pesan dan Nasihat-Nasihatnya
# 3           Fiqih Muslim: Problematika Kaum Laki-laki
# 4                Kisah Akhir Hayat Orang-Orang Zhalim
# 5        Fiqih Muslimah : Problematika Kaum Perempuan
# 6                                    Theology of Hope
# 7                             Pada Jejak Sang Kekasih
# 8   Moderasi Beragama dan Pergulatan Wacana dalam ...
# 9     Panduan Muslimah Jatuh Cinta Lewat Jalur Langit
# 10  Rahasia Sukses Budidaya Ikan Patin Secara Inte...
# 11              Rahasia Sukses Budi Daya Burung Walet
# 12  Buku Pintar Teknik Produksi Benih Ikan, Berdas...
# 13                 Pedoman Sukses Budi Daya Ikan Lele
# 14     Untung Dari Bisnis Domba & Kambing Ala Mt Farm
# 15        Potensi Transfer Embrio Kerbau Di Indonesia
# ...

# %% [markdown]
# <div class="ProductCard_cardContent__fawWr flex flex-col gap-y-2 p-4" data-testid="productCardContent" data-sentry-element="CardContent" data-sentry-source-file="ProductCard.tsx">

# %%
data
# Out:
# <div class="ProductCard_cardContent__fawWr flex flex-col gap-y-2 p-4" data-sentry-element="CardContent" data-sentry-source-file="ProductCard.tsx" data-testid="productCardContent"><div class="ProductCard_imageWrapper__WWY2H relative mx-auto"><div class="ProductCard_oosLabelBg__Xb3JX absolute -inset-x-4 top-0 flex h-full items-center justify-center"><span class="peer-disabled:cursor-not-allowed peer-disabled:opacity-70 text-red-500 bg-red-50 text-s-medium rounded-xs py-1 px-2 opacity-1" data-sentry-component="Label" data-sentry-source-file="Label.tsx" data-testid="productCardOosLabel">Stok Habis</span></div><div data-sentry-component="Image" data-sentry-source-file="Image.tsx"><img alt="Keterampilan Membatik untuk Anak" class="object-contain" data-nimg="fill" data-sentry-element="Image" data-sentry-source-file="ProductCard.tsx" data-testid="productCardImage" decoding="async" loading="lazy" src="https://image.gramedia.net/rs:fit:256:0/plain/https://cdn.gramedia.com/uploads/items/keteram
# ...

# %%
judul_baru = []
author_baru = []
images_baru = []
link_baru = []
for data in soup.find_all('div', {'class':'ProductCard_cardContent__fawWr flex flex-col gap-y-2 p-4'}):
    try:
        judul_baru.append(data.find('h2', {'class':'line-clamp-2'}).get_text())
    except:
        judul_baru.append(None)
    try:
        author_baru.append(data.find('div', {'class':'truncate text-2xs-medium text-neutral-500'}).get_text())
    except:
        author_baru.append(None)
    try:
        images_baru.append(data.find('img', {'class':'object-contain'})['src'])
    except:
        images_baru.append(None)
    try:
        link_baru.append(data.find('a', {'data-sentry-element':'LinkComponenent'}['href']))
    except:
        link_baru.append(None)

# %%
author_baru = []

for data in soup.find_all('div', {'class':'ProductCard_cardContent__fawWr flex flex-col gap-y-2 p-4'}):

# %%
images_baru = []

for data in soup.find_all('div', {'class':'ProductCard_cardContent__fawWr flex flex-col gap-y-2 p-4'}):

# %%
link_baru = []

for data in soup.find_all('div', {'class':'ProductCard_cardContent__fawWr flex flex-col gap-y-2 p-4'}):
    # try:
        print(data.find('a', {'data-sentry-element':'LinkComponenent'})['href'])
    # except:
    #     link_baru.append(None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[110], line 5
#       1 link_baru = []
#       3 for data in soup.find_all('div', {'class':'ProductCard_cardContent__fawWr flex flex-col gap-y-2 p-4'}):
#       4     # try:
# ----> 5         print(data.find('a', {'data-sentry-element':'LinkComponenent'})['href'])
#       6     # except:
#       7     #     link_baru.append(None)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
judul_baru_2 = []
author_baru_2 = []
images_baru_2 = []
link_baru_2 = []

for data in soup.find_all('a', {'data-sentry-element':'LinkComponenent'}):
    try:
        judul_baru_2.append(data.find('h2', {'class':'line-clamp-2'}).get_text())
    except:
        judul_baru_2.append(None)
    try:
        author_baru_2.append(data.find('div', {'class':'truncate text-2xs-medium text-neutral-500'}).get_text())
    except:
        author_baru_2.append(None)
    try:
        images_baru_2.append(data.find('img', {'class':'object-contain'})['src'])
    except:
        images_baru_2.append(None)
    try:
        link_baru_2.append(data['href'])
    except:
        link_baru_2.append(None)

# %%
link_baru_2
# Out:
# ['https://www.gramedia.com/products/new-media-dan-dakwah',
#  'https://www.gramedia.com/products/tafsiran-alkitab-bagi-orang-percaya-perjanjian-baru--buku-2',
#  'https://www.gramedia.com/products/rumi--samudra-pesan-dan-nasihatnasihatnya',
#  'https://www.gramedia.com/products/fiqih-muslim-problematika-kaum-lakilaki',
#  'https://www.gramedia.com/products/kisah-akhir-hayat-orangorang-zhalim',
#  'https://www.gramedia.com/products/fiqih-muslimah--problematika-kaum-perempuan',
#  'https://www.gramedia.com/products/theology-of-hope',
#  'https://www.gramedia.com/products/pada-jejak-sang-kekasih',
#  'https://www.gramedia.com/products/moderasi-beragama-dan-pergulatan-wacana-dalam-ruang-publik',
#  'https://www.gramedia.com/products/panduan-muslimah-jatuh-cinta-lewat-jalur-langit',
#  'https://www.gramedia.com/products/rahasia-sukses-budidaya-ikan-patin-secara-intensif',
#  'https://www.gramedia.com/products/rahasia-sukses-budidaya-burung-walet',
# ...

# %%
df_scrap = pd.DataFrame()

df_scrap['judul'] = judul
df_scrap['author_buku'] = author
df_scrap['link_gambar'] = image
df_scrap['link_product'] = link_web

# %%
print(len(author_baru))
print(len(judul_baru))
print(len(images_baru))
print(len(link_baru))
# Out:
# 41
# 41
# 41
# 41

# %%
df_scrap = pd.DataFrame()

df_scrap['judul'] = judul_baru_2
df_scrap['author_buku'] = author_baru_2
df_scrap['link_gambar'] = images_baru_2
df_scrap['link_product'] = link_baru_2

# %%
df_scrap
# Out:
#                                                 judul  \
# 0                                New Media dan Dakwah
# 1   Tafsiran Alkitab bagi Orang Percaya, Perjanjia...
# 2         Rumi : Samudra Pesan dan Nasihat-Nasihatnya
# 3           Fiqih Muslim: Problematika Kaum Laki-laki
# 4                Kisah Akhir Hayat Orang-Orang Zhalim
# 5        Fiqih Muslimah : Problematika Kaum Perempuan
# 6                                    Theology of Hope
# 7                             Pada Jejak Sang Kekasih
# 8   Moderasi Beragama dan Pergulatan Wacana dalam ...
# 9     Panduan Muslimah Jatuh Cinta Lewat Jalur Langit
# 10  Rahasia Sukses Budidaya Ikan Patin Secara Inte...
# 11              Rahasia Sukses Budi Daya Burung Walet
# 12  Buku Pintar Teknik Produksi Benih Ikan, Berdas...
# 13                 Pedoman Sukses Budi Daya Ikan Lele
# 14     Untung Dari Bisnis Domba & Kambing Ala Mt Farm
# 15        Potensi Transfer Embrio Kerbau Di Indonesia
# ...

# %% [markdown]
# https://www.tokopedia.com/search?navsource=&q=gundam&search_id=20241114141656C3DEB241712BD7100ODZ&srp_component_id=02.01.00.00&srp_page_id=&srp_page_title=&st=

# %%
driver = webdriver.Chrome()
driver.get('https://www.tokopedia.com/search?navsource=&q=gundam&search_id=20241114141656C3DEB241712BD7100ODZ&srp_component_id=02.01.00.00&srp_page_id=&srp_page_title=&st=')
time.sleep(4)
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
driver.close()

# %%
soup
# Out:
# <html data-rh="lang,translate" lang="id" translate="no"><head>
# <title>Jual gundam | Tokopedia</title>
# <meta charset="utf-8"/>
# <meta content="initial-scale=1, minimum-scale=1, maximum-scale=5, user-scalable=yes, width=device-width" name="viewport"/>
# <link crossorigin="" href="https://assets.tokopedia.net" rel="preconnect"/><link href="https://assets.tokopedia.net" nonce="" rel="dns-prefetch"/>
# <link crossorigin="" href="https://gql.tokopedia.com" rel="preconnect"/><link href="https://gql.tokopedia.com" nonce="" rel="dns-prefetch"/>
# <link crossorigin="" href="https://googleads.g.doubleclick.net" rel="preconnect"/><link href="https://googleads.g.doubleclick.net" nonce="" rel="dns-prefetch"/>
# <link crossorigin="" href="https://www.google-analytics.com" rel="preconnect"/><link href="https://www.google-analytics.com" nonce="" rel="dns-prefetch"/>
# ...

# %%
<span class="OWkG6oHwAppMn1hIBsC3pQ==">BANDAI Plamo HGUC Moon Gundam Clear Color</span>

# %%
barang = []
driver = webdriver.Chrome()
for page in range(1,3):
    driver.get(f'https://www.tokopedia.com/search?navsource=&page={page}&q=gundam&search_id=20241114142053EF07D841BF9E843592WR&srp_component_id=02.01.00.00&srp_page_id=&srp_page_title=&st=')
    time.sleep(3)

    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    
    barang += [data.get_text() for data in soup.find_all('span', {'class':'OWkG6oHwAppMn1hIBsC3pQ=='})]

# %%
barang
# Out:
# ['Pinset Gundam Nipper Hobby Tools',
#  'Cutting Mat A3 Gundam Hobby Tools Double Side',
#  'AIRBRUSH GUNDAM PENBRUSH MODEL KIT GUNDAM GUNPLA AIR BRUSH',
#  'SHUMO Lemari Hias Pajangan Kaca Action Figure | Rak Display Gundam Lego | Kabinet Besi Sliding Minimalis',
#  'HG HGUC GUNDAM X DIVIDER BANDAI MODELKIT ORIGINAL 1/144',
#  'Tools Set Gundam Gunpla - Tool Kit Rakit Gundam (Single Pack)',
#  'Tools Set Gundam Gunpla - Tool Kit Rakit Gundam (Double Pack)',
#  ' Double Head Model Cotton Swab MS077 Cotton Bud Gundam Model Kit',
#  'BANDAI Plamo MG IBO ASW-G-08 Gundam Barbatos',
#  'BANDAI Plamo HGUC RX-78-2 Gundam',
#  'ENTRY GRADE STRIKE GUNDAM',
#  'BANDAI Plamo SD Gundam Ex-Standard Rising Freedom Gundam',
#  'BANDAI Plamo HG 1/144 Gundam Aerial',
#  'Rak Display Funko Pop NENDOROID GUNDAM - Etalase Action Figure - PUTIH',
#  'Stand Action Figure Anime Transparan Stand Base Gundam Untuk 6 Inch',
#  'Fuji - With Figure Pandem Rocket Bunny Nissan GTR R35 EXIA Mecha Gundam RX-78',
# ...

# %%
driver.execute_script()
